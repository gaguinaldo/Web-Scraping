# %%
import requests as r
from bs4 import BeautifulSoup as soup
import pandas as pd
import time

# %%
file = '/Users/gta/Desktop/web-scraping/violations/data.csv'

# %%
df = pd.read_csv(file)

# %%
df['url'] = ''
df['violation_data'] = ''
df['equipment'] = ''
df.shape
# Out:
# (3888, 7)

# %%
baseUrl1 = 'http://www3.aqmd.gov/webappl/fim/prog/novdetail.aspx?novid='
baseUrl2 = '&notice_type=NOV&fac_id='

# %%
for index, row in df.iterrows():
    df.set_value(index, 'url', baseUrl1 + str(row['notification']) + baseUrl2 + str(row['facility id']))

# %%
df = df.iloc[1800:2000]

# %%
df.shape
# Out:
# (200, 7)

# %%
index_except = []

for index, row in df.iterrows():   
    try:
        data = r.get(row['url'])
        print(data, index)
        page_soup = soup(data.text, 'html.parser')
        violation = page_soup.find_all('span')[16].text.strip()
        violationEquipment = page_soup.find_all('span')[18].text.strip()
        df.set_value(index, 'violation_data', violation)
        df.set_value(index, 'equipment', violationEquipment)
        print(violation)
    
    except:
        index_except.append(row['notification'])
# Out:
# <Response [200]> 1800
# <Response [200]> 1801
# <Response [200]> 1802
# Selling coatings within the SCAQMD's area of jurisdiction that exceeded the VOC limits set forth by SCAQMD Rule 1113.
# <Response [200]> 1803
# (1) 1st SAM Report late; (2) Failed to conduct annual tune-ups; (3) Exceeded limit per condition C1.4 on 23 days, Exceeded limit per conditon C1.5 for 3 months, Records failed to demo compliance with asphalt loading per conditions C1.1 and C1.3;
# <Response [200]> 1804
# (1) Failed to reconcile quarterly NOx emissions in the last quarter, and (2) NOx emissions from the beginning of the 2011 Compliance Year through the end of the last quarter exceeded the annual NOx emissions allocation in effect at the end of the
# <Response [200]> 1805
# operating an in-use stationary diesel generator engine, > 50 hp, located < 100 m from an existing school, without reducing the diesel PM rate in accordance with the appropriate compliance schedule
# <Response [200]> 1806
# Operating 4 Raypak boilers rated at 1.25 Million BTU w/o a registration; Failure to demonstrate compliance with 30ppm NOx emissions limit for 2 Parker Boilers; Failure to submit a multi-engine compliance plan by 1/1/2011 in accordance w/ Table 4 of 1472
# <Response [200]> 1807
# operating an in-use stationary diesel generator engine, > 50 hp, located < 100 m from an existing school, without reducing the diesel PM rate in accordance with the appropriate compliance schedule
# <Response [200]> 1808
# Operating a Title V facility without first obtaining a Title V permit.  Operating mixers and spray booths at a Title V facility without a permit.
# <Response [200]> 1809
# 1) NOT WETTING ACWM.  2) NOT LABELING THE ACWM BAGS PER 1403e1A&B.;
# <Response [200]> 1810
# (1) Operation of photoresist process equipment at a semiconductor manufacturing facility without venting VOC containing vapors to an approved emission control system for 6 days (2) Destruction Efficiency of 95% was not maintained for TO (C364) during
# <Response [200]> 1811
# (1) Operation of photoresist process equipment at a semiconductor manufacturing facility without venting VOC containing vapors to an approved emission control system for 6 days (2) Destruction Efficiency of 95% was not maintained for TO (C364) during
# <Response [200]> 1812
# (1) Operation of photoresist process equipment at a semiconductor manufacturing facility without venting VOC containing vapors to an approved emission control system for 6 days (2) Destruction Efficiency of 95% was not maintained for TO (C364) during
# <Response [200]> 1813
# Operating a portable Caterpillar brand, model 3054, serial number 5YS11555, internal combustion engine (ICE) greater than 50 brake horsepower without a permit to operate.
# <Response [200]> 1814
# fAILURE TO COMPLY WITH PERMIT A/N434296 CONDITION D. EXCEEDANCE OF VOC LIMIT AT THE EXHAUST OF THE VRS(16 COUNTS). FAILURE TO COMPLY WITH PERMIT A/N434295 CONDITION E. FAILURE TO NOTIFY THE DISTRICT WITHIN 24 HRS. IN THE EVEN TOF A CEMS OR RECORDER FAILUR
# <Response [200]> 1815
# Installing and operating  (31) chemical reactions & (2) carcinogenic packaging with (A) carcinogenic transfer lines without valid authorization to install & to operate.
# <Response [200]> 1816
# Failing to submit a completed and signed form 500-SAM on or before 8/31/2013
# <Response [200]> 1817
# Intalling a John Deere diesel fueled ICE, M/N 4045TF290, S/N PE4045R923519, without a written permit to construct.
# <Response [200]> 1818
# Operating one Clarke diesel fueled ICE, Model # VMFP-04HT 3431H, s/n 22B-2546, rated 87 bhp without a valid permit. Failure to maintain engine operating logs.
# <Response [200]> 1819
# 1.No Notification 24 hours prior to excavation.2.Not implementing the approved mitigation plan upon discovering VOC contaminated soil.3.not re-notifying AQMD within 24 hours of detection of VOC contaminated soil.4.Monitoring records not available onsite
# <Response [200]> 1820
# R109(c): failure to maintain daily records of operations. R203(b): failure to comply with condition #3 of P/O F23973. R1151(e)(1): possession of automotive coatings that are not compliant with section d(1) of Rule 1151.
# <Response [200]> 1821
# failure to maintain daily records of operations
# <Response [200]> 1822
# Operating phase II vapor recovery of a gasoline dispensing system with a torn hose
# <Response [200]> 1823
# Failure to conduct weekly inspections of spray booths required by conditions #* and #9 for P/Os D76736, D76737, D76738.  Failure to conduct annual inspection of dust collectors associated with woodworking operations.
# <Response [200]> 1824
# Failure to conduct weekly inspections of spray booths required by conditions #* and #9 for P/Os D76736, D76737, D76738.  Failure to conduct annual inspection of dust collectors associated with woodworking operations.
# <Response [200]> 1825
# Use of prohibited materials in Printing Press D72.  Exceeded fuel limit on RTO C69.  Operation of Printing Presses D72 and D73 and RTO C69 with expired permits.  Failure to operate temperature recorder monitoring RTO C69 during operation of the RTO.
# <Response [200]> 1826
# <Response [200]> 1827
# Operating a Caterpillar Engine rated 157 HP (SN E5M00295) without first obtaining a SCAQMD P/O.
# <Response [200]> 1828
# The facility was operating (3) paint spray booths equipped with heaters without a valid SCAQMD P/O.
# <Response [200]> 1829
# Operating gasoline dispensing equipment with an uncertified component-Facility is operating with a Husky model 4885 P/V Vent Valve.  Failure to maintain a semi annual testing schedule.
# <Response [200]> 1830
# Operating gasoline dispensing equipment with an uncertified component-Facility is operating with a Husky model 4885 P/V Vent Valve.  Failure to maintain a semi annual testing schedule.
# <Response [200]> 1831
# Operating gasoline dispensing equipment with an uncertified component-Facility is operating with a Husky model 4885 P/V Vent Valve.  Failure to maintain a semi annual testing schedule.
# <Response [200]> 1832
# Operating a gasoline dispensing facility contrary to CARB Executive Orders and manufacturer's specifications: nozzle #4 missing faceplate
# <Response [200]> 1833
# Operation of Phase II Vapor Recovery equipment with major defects. Failure to conduct annual Vapor Recovery Reverification tests in 2011 and 2012.
# <Response [200]> 1834
# The facility was operating an E-85 disp fac contrary to the conditions specified in the PC; failed to conduct reverification tests in the same testing months for the gdf; exceeded the monthly throughput limit for the gdf in 2013
# <Response [200]> 1835
# operation of gasoline dispensing and storage tank without a valid permit to operate.
# <Response [200]> 1836
# Failure to provide records. Failure to provide current periodic compliance inspection. Failure to provide current Healy Weekly and Quarterly Inspections.
# <Response [200]> 1837
# shall not build, erect, install, alter or replace any equipment  without first obtaining written authorization
# <Response [200]> 1838
# Operating a Lindus PM80 petroleum solvent dry cleaning machine with inactive permit and failing to perform monthly leak inspection checks and maintaining the records, and calculate the Facility Annual Mileage report for 2012.
# <Response [200]> 1839
# Operating a gasoline dispensing facility with a major defect: upside down breakaway (Healy ) installed at fueling point #10
# <Response [200]> 1840
# Violation of condition #34 of P/O limiting facility to not exceed 12,500 gallons per month.
# <Response [200]> 1841
# 1) operating the Wagner Powder coating equipment without a permit.
# <Response [200]> 1842
# 1) operating the Wagner Powder coating equipment without a permit.
# <Response [200]> 1843
# 1) failure to maintain an enigine operating log; and 2) operation exceeding allotted hours as specified in Rule 1470 and P/O
# <Response [200]> 1844
# Operating a gasoline dispensing facility with a major defect: poppet on regular tank-closest to premium tank- is inoperative
# <Response [200]> 1845
# Operated contrary to condition #3 of P/O R-D84232 by operating the diesel-fueled IC engine more than 200 hours in 2012.
# <Response [200]> 1846
# Installing one gasoline dispenser and altering one underground storage tank without a permit to construct: failure to conduct vapor recovery testing within 10 days of initial operation (Performance Testing)
# <Response [200]> 1847
# Excess emissions of fugitive dust crossing over property line from active field renovation operation; failure to apply appropriate best available control measures (e.g., adequate water) to stabilize unstable surface area.
# <Response [200]> 1848
# Excess emissions of fugitive dust crossing over property line from active field renovation operation.
# <Response [200]> 1849
# Operating a Parker boiler rated at 1,075,000 BTU manufactured in 1997 (over 15 years old) without demonstrating compliance with or exemption from emission limits.
# <Response [200]> 1850
# exceeding permit condition limits: 1. P/O D47918 cond 4 of loading more than 54tons/mo of cement in silo 2. P/O D49298 cond 5 exceeding daily usage of diesel 3. P/O F97693 cond 6 exceeding 667 lbs VOC/mo for April, May, June in 2011
# <Response [200]> 1851
# Failure to condcut reverification tests annually.
# <Response [200]> 1852
# Allowing track-out from an active operation at the conclusion of a workday, in violation of Rule 403 (d)(4)
# <Response [200]> 1853
# Allowing track-out from an active operation at the conclusion of a workday, in violation of Rule 403 (d)(4)
# <Response [200]> 1854
# Allowing track-out from an active operation at the conclusion of a workday, in violation of Rule 403 (d)(4)
# <Response [200]> 1855
# The company failed to demonstrate compliance with the emissions reqts of 1146.2(c)(1) after exceeding 9,000 therms of annual heat input for the LAARS Boiler (sn C96H00622).
# <Response [200]> 1856
# -203(a) for failing to obtain a permit to operate the blenders on the Bosch creamer, Soy milk, and Almond milk production lines;
# -203(b) for exceeding the 400,000 GPD limit set on the permit G6498 wastewater treatment system
# <Response [200]> 1857
# <Response [200]> 1858
# <Response [200]> 1859
# <Response [200]> 1860
# FAILURE TO SUBMIT ACCURATE QCER FOR 2ND  Q OF RECLAIM CYCLE 2 COMPLIANCE YEAR 2011. 2)FAILURE TO MAINTAIN AND OPERATE A DIRECT MONITORING DEVICE TO CONTINUOSLY MEASUREO2 CONC FOR D38. 3)FAILURE TO REPORT DATA BY MEANS OF DATA ACQUISITION AND HANDLING
# <Response [200]> 1861
# OPERATING A COOLING TOWER WITHOUT A WRITTEN PERMIT TO OPERATE.
# <Response [200]> 1862
# The facility is in violation of the 3 hour average 5 ppm NOx emission limit.
# <Response [200]> 1863
# The facility is in violation of the 3 hour average 5 ppm NOx emission limit.
# <Response [200]> 1864
# The facility didn't operate the flare in such a manner that minimized all flaring on 11/8 - 11/9/12.  The facility is in violation of the 3 hour average 5 ppm NOx emission limit on 11/9/12.
# <Response [200]> 1865
# INACURATE CERTIFICATION OF QUARTERLY EMISSIONS FOR 1ST, 2ND, 3RD AND 4TH QUARTERS. FAILURE TO REPORT DATA BY MEANS OF THEDATA ACQUISITION AND HANDLING SYSTEM FOR THE MISSING HOURS IN ACCORDANCE WITH THE APPLICABLE PROCEDURES FOR SUBSTITUTING MISSING DATA.
# <Response [200]> 1866
# The operator shall vent this equip. to an APC consisting of a SCR which wasn't in full use.  If the heater reaches 570 deg F, the flue gas shall be vented through the SCR system using ammonia injection  on 11/12/11.  The 3 hr avg 5 ppm NOx was exceeded on
# <Response [200]> 1867
#
# <Response [200]> 1868
# Did not submit the 2012 Compliance Year Annual Permit Emissions report by the 8/29/2013 deadline
# <Response [200]> 1869
# OPERATING A GASOLINE DISPENSING FACILITY WITHOUT A VALID PERMIT TO OPERATE; FAILURE TO CONDUCT REVERIFICATION TESTS SEMIANNUALLY; INOPERABLE VACUUM PUMP ON DISPENSER WITH FUELING PRINT #5 AND #6
# <Response [200]> 1870
# Failed to reconcile quarterly NOx emissions in the 2nd & 3rd Quarters;  NOx emissions from the beginning of the 2011 compliance year through the end of the second and third quarter exceeded the annual NOx emissions allocation in effect at the end of the
# <Response [200]> 1871
# SEE ATTACHMENT
# <Response [200]> 1872
# FACILITY PERMIT 800089 FIXED ROOF TANK 150X103, DEVICE 915: 1)OPERATING CONTRARY TO CONDITION E336.1 BY VENTING GASES TO THE ATMOSPHERE. 2) FAILURE TO REPORT THE ABOVE DEVIATION AS REQUIRED BY CONDITION 22(B) OF SECTION K.
# <Response [200]> 1873
# OPERATING ALKY UNIT PROCESS 8 SYSTEM 8 CONTRARY TO CONDITION #2 SECTIONE; ADMINISTRATIVE CONDITION OF FACILITY PERMIT 800089.
# <Response [200]> 1874
# 1/29/13 - TCID#7143.01, VALVES ID#695.00, 27359.00  LEAKING IN EXCESS OF 50,000 PPM OPEN ENDED LINES: 4626,4627,4374,40013,4004. 1/30/13 - VALVES ID#33623,33558 - LEAKING IN EXCESS OF 50, 000 PPM VOC.
# <Response [200]> 1875
# Operationg Devices 653, 688 and 671, contrary to condition # 4, Section E Administrative Conditions of facility permit # 800089.
# <Response [200]> 1876
# Failure to minimize flaring due to mistakenly shutting down four water circulation pumps at the hydrometer cooling tower.
# <Response [200]> 1877
# (C2283, C2284) Electrostatic precipitators capacity in excess of 20%
# <Response [200]> 1878
#
# <Response [200]> 1879
# Failure to maintain the SCR bypass stack damper at a fully closed position.
# Failure to notify the District within 1 hour of unplanned opening of bypass stack damper.
# <Response [200]> 1880
# RESUME OPERATION OF A GASOLINE TRANSFER AND DISPENSING EQUIPMENT THAT HAD FAILED THE APPLICABLE PERFORMANCE OR RE VERIFICATION TESTS.
# <Response [200]> 1881
# RESUME OPERATION OF A GASOLINE TRANSFER AND DISPENSING EQUIPMENT THAT HAD FAILED THE APPLICABLE PERFORMANCE OR RE VERIFICATION TESTS.
# <Response [200]> 1882
# RESUME OPERATION OF A GASOLINE TRANSFER AND DISPENSING EQUIPMENT THAT HAD FAILED THE APPLICABLE PERFORMANCE OR RE VERIFICATION TESTS.
# <Response [200]> 1883
# The facility did not hold sufficient NOx RTCs at the commencement of the 2012 RECLAIM Cycle 2 compliance year to comply w facility permit conditions I296.1,I296.2,I296.3, I296.4, & I296.5
# <Response [200]> 1884
# did not electronically report daily mass emissions of NOX and daily staus codes fo reach Major and daily staus codes for each manor source fo r8/31/2011 the compliance yeat 2011 cycle 2, 1st qrtr QCER submitted to SCAQMD was inaccurate for total NOX emsns
# <Response [200]> 1885
# Operating one natural gas fired boiler rated 840,000 btu/hr over 15 years old without demonstrating emission limits being met.
# <Response [200]> 1886
# Operation of stationary diesel-fueled emergency ICE, >50 bhp, 100 meters or less from an existing school, without reducing disel PM emissions as required.  Operating contrary to permit conditions.
# <Response [200]> 1887
# operating an in-use stationary diesel generator engine, > 50 bhp, that is location within 100 m from an existing school, without demonstrating 85% PM reduction (or lower), and for 203(b) for operating contrary to Condition #5 of AQMD P/O F84802.
# <Response [200]> 1888
# A RATA for device #20 was not completed in a timely manner.  The quarterly RTU report of NOx emissions for device #19 in the 2nd quarter was inaccurate. The 4th quarter QCER was inaccurate
# <Response [200]> 1889
# DEMOLITION OF THE FLOATING ROOF OF TANK D WITHOUT PRIOR 10 WORKING DAY NOTIFICATION.
# <Response [200]> 1890
# DEMOLITION OF THE FLOATING ROOF OF TANK D WITHOUT PRIOR 10 WORKING DAY DEMOLITION NOTIFICATION.
# <Response [200]> 1891
# Exceeded monthly gasoline throughput limit of 150,000 gallons (from permit to operate N26001)-June 2011 to August 2011, October 2011 to January 2013; Exceeded annual gasoline throughput limit of 1,800,000 gallons for 2012; Operating gasoline dispensing
# <Response [200]> 1892
# DEMOLITION OF TANK S WITHOUT PRIOR 10 WORKING DAY DEMOLITION NOTIFICATION
# <Response [200]> 1893
# DEMOLITION OF TANK S WITHOUT PRIOR 10 WORKING DAY DEMOLITION NOTIFICATION
# <Response [200]> 1894
# DEMOLITION OF TANK S WITHOUT PRIOR 10 WORKING DAY DEMOLITION NOTIFICATION.
# <Response [200]> 1895
# DEMOLITION OF TANK S WITHOUT PRIOR 10 WORKING DAY DEMOLITION NOTIFICATION.
# <Response [200]> 1896
# FAILED ENGINE ANNUAL SOURCE TEST OF ENGINE #5 ON 1/18/11.  OPERATING ENGINE #5 CONTRARY TO PERMIT CONDITION #11 OF PERMIT TO OPERATE (G2967).
# <Response [200]> 1897
# FAILED ANNUAL SOURCE TEST OF ENGINE #2 ON 4/14/11.  OPERATING ENGINE #2 CONTRARY TO PERMIT CONDITION #11 OF PERMIT TO OPERATE (G2959).
# <Response [200]> 1898
# Operating an emergency fire pump rated greater than 50BHP without a permit to operate.
# <Response [200]> 1899
# Permit F42612, condition 11; Permit F88391, conditions 3, 4, 6, 7
# <Response [200]> 1900
# The facility failed to first obtain a permit before modifying and operating tank no. 7; failed to operate the vacuum degreaser and solv. recycl. system in compliance w/conditions specified in Title V P/O
# <Response [200]> 1901
# Failure to scavenge all solvent vapor through the regenerative carbon adsorber; failure ot correct exhaust concentration exceedance w/in 15 days; The carbon adsorber shall not be bypassed during desorption, The exhaust concentration shall be measure weekl
# <Response [200]> 1902
# Failure to submit NESHAP form F-13 signed to the EO by 2/1/12; Operating equipment at a Title V without first obtaiining a Title V Permit to Operate; Operating contrary to conditions 3,4,6 on P/O F88391; Operating contrary to conditions 1,4,6,8 on PC A/N
# <Response [200]> 1903
# Exceeding tank concentration limits % by weight, Exceeding Tank Temperatures, Using compounds not listed in P/O inside of tanks; exceeding pH limit of Nitric Scrubber; Failure to conduct source test of Nitric Scrubber
# <Response [200]> 1904
# Failure to operate equipment at a Title V facility in compliance with all terms, requirements, and conditions specified in the Title V permit at all times.
# <Response [200]> 1905
# Failure to comply with Title V Permit conditions.
# <Response [200]> 1906
# Failure to conduct vapor recovery reverification testing semiannually (according to monthly gasoline throughputs); failure to conduct vapor recovery reverification testing in the same months established by performance test to be February and August;
# <Response [200]> 1907
# DISCHARGING QUANTITIES OF AIR CONTAMINANTS WHICH CAUSED INJURY, DETRIMENT, NUISANCE OR ANNOYANCE TO A CONSIDERABLE NUMBER OF PERSONS.
# <Response [200]> 1908
# DISCHARGING QUANTITIES OF AIR CONTAMINANTS WHICH CAUSED INJURY, DETRIMENT, NUISANCE OR ANNOYANCE TO A CONSIDERABLE NUMBER OF PERSONS.
# <Response [200]> 1909
# DISCHARGING QUANTITIES OF AIR CONTAMINANTS WHICH CAUSED INJURY, DETRIMENT, NUISANCE OR ANNOYANCE TO A CONSIDERABLE NUMBER OF PERSONS.
# <Response [200]> 1910
# <Response [200]> 1911
# Exceeding 200 hours in any one year, which includes 50 hours in any one year for maintenance and testing purposes and 4.2 hours in any one month for testing and maitnenance purposes as prohibited in condition #7 of P/O #G27057.
# <Response [200]> 1912
# Failure to comply with Notice to Compy #E19913. Failure to comply with permit conditions #30 and 34. Failure to maintain required records. Failure to provide ISD alarm logs. Failure to provide monthly throughput records.
# <Response [200]> 1913
# Operating gasoline dispensing equipment with a major defect-the maint hose on dispenser number 2 is the wrong model number (it is a VSTA whiphose should be a VDV and have a liquid removal pick up indicator). Failure to maintain a semi annual test schedule
# <Response [200]> 1914
# The company was operating a diesel fueled Detroit ICE rated greater than 50 HP, without a valid SCAQMD permit to operate.
# <Response [200]> 1915
# Operating engine more than 20 hours per year for maintenance and testing purposes
# <Response [200]> 1916
# Allowing visible fugitive dust emissions from the operation of a Schibeci asphalt grinder with serial -004-000090 that remained visible in the atmosphere beyond the property line of the emission source, in violation of Rule 403 (d)(1)(A).
# <Response [200]> 1917
# Failure to: Clean button and lint traps daily; store waste in closed container; inspect dry cleaning system monthly for liquid and vapor leaks; maintain dry cleaning machine operating records.
# <Response [200]> 1918
# Failure to: Clean button and lint traps daily; store waste in closed container; inspect dry cleaning system monthly for liquid and vapor leaks; maintain dry cleaning machine operating records.
# <Response [200]> 1919
# Failure to: Clean button and lint traps daily; store waste in closed container; inspect dry cleaning system monthly for liquid and vapor leaks; maintain dry cleaning machine operating records.
# <Response [200]> 1920
# Operating one paint spray booth without a valid written permit to operate. Failure to maintain VOC records.
# <Response [200]> 1921
# Failure to submit a timely and complete title V permit renewal application.
# <Response [200]> 1922
# Allowing track-out to extend greater than 25 feet in length from an active operation.
# <Response [200]> 1923
# Installing 1 ICE w/o first obtaining a P/C; operation of 1 boiler >1 million BTUs w/o a valid reg; failure to implement I&M; plan approved by the district; failure to submit qtrly rep w/in 15 days of the end of each qtr; failure to submit 1415 reg
# <Response [200]> 1924
# Failure to implement I&M; plan approved by the district; failure to submit quarterly report within 15 days of the end of each quarter.
# <Response [200]> 1925
# 203(a): operation of diesel engine >50 hp w/o PO
# <Response [200]> 1926
# Failure to show compliance by conducting vapor recovery repairs at the above location address without a current vapor recovery system repair ICC
# <Response [200]> 1927
# Failure to conduct annual vapor recovery test as required for non-retail gas dispensing facilitiy
# <Response [200]> 1928
# 203 (b) - Exceeding the annual and monthly maximum quantity of gasoline dispensed as prohibited in condition #11 of P/O #N12864.
# <Response [200]> 1929
# Allowing track-out to extend 25 feet or more in cumulative length from the point of origin from an active operation
# <Response [200]> 1930
# using non-compliant glue R 1168
# <Response [200]> 1931
# Failure to provide records demonstrating compliance. Failure to conduct vapor recovery testing annually. Testing should have been conducted by 1/31/12
# <Response [200]> 1932
# Operating gasoline dispensing equipment conrary to CARB Executive Orders and manufacturer's certification-Ball valve "C" on the clean air separator is in the "open" position.
# <Response [200]> 1933
# Operating one paint spray booth without a valid written permit to operate. Failure to maintain VOC usage records onsite.
# <Response [200]> 1934
# 1. Operating contrary to permit conditions:  Failure to record alarm event information; manually clearing alarm warnings without proof of repairs; failure to conduct leak rate and cracking pressure of pressure/vacuum vent valve test within 3 years of
# <Response [200]> 1935
# Failure to show complianc eby not performing the annual vapor reverification test due every April
# <Response [200]> 1936
# facility operating paint spray booth with missing filter; failure to keep and maintain booth in good operating condition; failure to keep, maintain, provide daily VOC usage logs.
# <Response [200]> 1937
# <Response [200]> 1938
# <Response [200]> 1939
# <Response [200]> 1940
# <Response [200]> 1941
# <Response [200]> 1942
# <Response [200]> 1943
# The company was operating an Isuzu diesel engine rated 173 HP (4 cyl) without a valid SCAQMD permit to operate.
# <Response [200]> 1944
# The company was operating an Isuzu engine (serial no. 71060-000036, rated 150 HP) without first obtaining a SCAQMD permit to operate
# <Response [200]> 1945
# Selling architectural coatings within the SCAQMD with a VOC content in excess of the limits in the Rule 1113 - Table of Standards 1 for the years: 2009 & 2011.
# <Response [200]> 1946
# failure to meet emissions limits for PM during operation with fuel oil (units # 1 & 2).
# <Response [200]> 1947
# failure to operate a Title V facility in compliance with all terms, requirements, and conditions specified in the Title V permit.
# <Response [200]> 1948
# Selling architectural coatings within the SCAQMD with a VOC content in excess of the limits listed in the Rule 1113 - Table of Standards for the years: 2010, 2011, & 2012
# <Response [200]> 1949
# 1) failed to conduct daily calibrations for each major source CEMs on various days; 2) Failed to report total daily mass emissions by 5:00 pm of the following day for Major sources on various days; 3) Failed to submit 1st, 2nd, and 3rd Quarter QCERs
# <Response [200]> 1950
# Operation of 2 diesel-fueled emergeny engines greater than 50 hp, located 100 meters or less from an existing school, without reducing diesel PM emissions as required.
# <Response [200]> 1951
# Operating an in-use stationary diesel generator engine, > 50 bhp, that is located within 100 m from an existing school, without demonstrating 85% PM reduction (or lower).
# <Response [200]> 1952
# Operating an in-use stationary diesel generator engine, > 50 bhp, that is located within 100 m from an existing school, without demonstrating 85% PM reduction (or lower).
# <Response [200]> 1953
# Operating an in-use stationary diesel generator engine, > 50 bhp, that is located within 100 m from an existing school, without demonstrating 85% PM reduction (or lower).
# <Response [200]> 1954
# Failure to submit an Emergency Burn Plan Application.  Failure to obtain a Burn Authorization Number. Failure to report.
# <Response [200]> 1955
# did not conduct relative accuracy test audit or alternative relative accuracy test by due date for turbines D1, D15, and D22
# <Response [200]> 1956
# Did not conduct relative accuracy test audit or alternative realtive accuracy test audit by due date for turbines D1, D8,D15 and D22.
# <Response [200]> 1957
# Operating a stationary diesel emergency generator engine: CAT 3208 without a valid permit and failing to demonstrate compliance with the emission limits for three Raypak boilers.
# <Response [200]> 1958
# Allowing track out to extend greater than 25 feet in cumulative length from an egress.  Did not install a track out device at the egress.
# <Response [200]> 1959
# Failure to conduct reverification test annually -monthly throughput is less than 100,000 gallons
# <Response [200]> 1960
# Operating a portable internal combustion engine rated over 50 bhp without a valid AQMD permit or CARB registration
# <Response [200]> 1961
# Operating a portable internal combustion engine rated over 50 bhp without a valid AQMD permit or CARB registration
# <Response [200]> 1962
# Operating a portable internal combustion engine rated over 50 bhp without a valid AQMD permit or CARB registration
# <Response [200]> 1963
# Failing to use best available control measures to minimize fugitive dust - 07-1: stabilizing disturbed soil at construction site.  Allowing trackout to extend more than 25 ft. from construction site.
# <Response [200]> 1964
# exceeding permit condition #3 of P/O F89639 of 38 gals of PERC per calendar year
# <Response [200]> 1965
# Operating a Raypak boiler rated at 1,999,000 btu/hr input manufactured in 1995 (over 15 years old) without demonstrating compliance with or exemption from emission limits.
# <Response [200]> 1966
# Operating a gasoline dispensing facility with major defects-torn main hose on #8 and contrary to CARB executive orders; nozzle #6 has a faulty insertion interlock mechanism
# <Response [200]> 1967
# Failure to conduct reverification test 6 months after last successful test. Failure to conduct periodic compliance inspection (2months after last one)
# <Response [200]> 1968
# Operating PERC dry cleaning machine without active permit to operate. Failure to keep recordkeeping forms. Failure to maintain environmental trained operator.
# <Response [200]> 1969
# failure to utilize CVBACM to control fugitive dust emissions, and allowance of fugitive dust emissions to cross proprty lines.
# <Response [200]> 1970
# operating a crude oil/waste water tank system wihtout a valid permit to operate
# <Response [200]> 1971
# Operating gasoline dispensing equipment with a major defect-operating gasoline dispensing equipment contrary to CARB Executive Orders and manufacturer's specifications- ball valves B and C on the clean air seperator are in the open during normal operation
# <Response [200]> 1972
# Operating one in use diesel fueled ICE >50 bhp located within 100 meters of an existing school without demonstrating diesel PM standards. Failure to maintain engine logs.
# <Response [200]> 1973
# failure to maintain ESP in good operating condition P/O F96650 cond. 2 and emitting white smoke greater than 20% opacity from ESP exhaust stack with P/O F96650 for more than 3 minutes in one hour
# <Response [200]> 1974
# Failure to conduct reverification test, based on established date of the facility's performance test date (May 2009)
# <Response [200]> 1975
# Failure to stay under the gasoline throughput limit of 655,000 gallons per month as stated on permit to operate N26736
# <Response [200]> 1976
# Failure to stay under the gasoline throughput limit of 655,000 gallons per month as stated on permit to operate N26736
# <Response [200]> 1977
# FAILURE TO SHOW COMPLIANCE BY OPERATING ABOVE FACILITY CONTRARY TO PERMIT CONDITION 30; NO ALARM LOG, NOT PERFORMING ANNUAL PERIODIC COMPLIANCE INSPECTION FOR 2012, NOT HAVING ANNUAL PERIODIC COMPLIANCE INSPECTION REPORT AVAILABLE FOR REVIEW; FAILURE TO
# <Response [200]> 1978
# failure to control track out from site egress of active operation to less than 25 feet in length.
# <Response [200]> 1979
# Failure to maintain gasoline dispensing equipment in accordance with CARB Executive Orders and manufacturer's specifications. Operating gasoline dispensing equipment with a major defect-torn whip hose on dispenser #3
# <Response [200]> 1980
# FAILING TO SUBMIT 2013 1ST HALF SAM IN A TIMELY MANNER
# <Response [200]> 1981
# FAILURE TO SUBMIT ONGOING COMPLIANCE STATUS AND EMISSION REPORT BY THE REQUIRED DUE DATE.
# <Response [200]> 1982
# Operating gasoline dispensing equipment with a major defect:  operating gasoline dispensing equipment contrary to CARB Executive orders-the main hose on #7 is installed upside down
# <Response [200]> 1983
# Failure to maintain equipment in good operating condition(Failed valve on T-630 caused an overflow and spill into containment berm)[R203(b)]
# <Response [200]> 1984
# Failure to maintain a semiannual test schedule (facility dispenses greater than 100,000 gallons per month)
# <Response [200]> 1985
# <Response [200]> 1986
# <Response [200]> 1987
# <Response [200]> 1988
# <Response [200]> 1989
# <Response [200]> 1990
# ACE Hardware Corporation reported that they sold non-compliant coatings within the AQMD's jurisdiction for 2009-2011 in violation of SCAQMD Rule 1113.
# <Response [200]> 1991
# Operating boilers between 400,000 btu and 1,000,000 btu without demonstrating compliance with emission limits.
# <Response [200]> 1992
# The facility was operating 7 Raypak boilers with max. heat input capacity of 400 K t0 990 K Btu/hr. that were more than 15 years old and failed to demonstrate compliance with the emission limits of paragraph (c)(1).
# <Response [200]> 1993
# failure to submit application for permit to construct for aztec boiler
# <Response [200]> 1994
# failure to conduct portable NOx analyzer test since 2010
# <Response [200]> 1995
# Failed to submit daily emissions report; Failed to submit daily emissions in a timely manner.
# <Response [200]> 1996
# 1) NO NOTIFICATION TO SOUTH COAST AQMD OF ASBESTOS REMOVAL. 2) NOT USING ACM REMOVAL PROCEDURES. 3) NOT COLLECTING AND PLACING ACM IN LABELED LEAK-TIGHT CONTAINERS. 4) NOT WETTING ACWM. 5) PERFORMED ASBESTOS REMOVAL WITHOUT VALID CAL OSHA (DOSH) REGISTRAT
# <Response [200]> 1997
# Failure to comply with Employee Commute Reduction Plan's Strategies for 2012, 2011 & 2010.
# <Response [200]> 1998
# Failure to comply with Title V Permit conditions: exceeded NOx hourly emission limit, failure to maintain mothly fuel usage records for boilers. Failure to submit summary of the concentration and/or emission rate data obtained from CEMS every six months.
# <Response [200]> 1999
# Violation of permit emissions limits

# %%
index_except
# Out:
# ['HRB2228',
#  'HRB2228',
#  'SRV98',
#  'HRB2212',
#  'HRB2213',
#  'HRB2213',
#  'SRV99',
#  'HRB2222',
#  'HRB2222',
#  'HRB2223',
#  'HRB2221',
#  'HRB2224',
#  'HRB2224',
#  'HRB2248',
#  'HRB2248',
#  'HRB2250',
#  'HRB2249',
#  'HRB2249']

# %%
df.to_csv('scrape11.csv', index=False)
